# %% [markdown]
# # Stage 5: Model Evaluation and Testing

# %% [markdown]
# This notebook focuses on evaluating the performance of the trained QSAR model using visualization.

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
