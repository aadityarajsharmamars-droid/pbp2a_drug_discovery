# %% [markdown]
# # Stage 1: Data Collection and Cleaning

# %% [markdown]
# This notebook covers the initial steps of collecting raw biological activity data and cleaning it for further analysis and model building.

# %%
import pandas as pd

# %%
from chembl_webresource_client.new_client import new_client

# %%
import numpy as np

# %%
from rdkit import Chem
