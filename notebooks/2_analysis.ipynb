# %% [markdown]
# # Stage 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# This notebook performs exploratory data analysis on the cleaned biological activity data and calculated molecular descriptors to understand the data distribution and relationships.

# %%
import pandas as pd

# %%
import numpy as np

# %%
from rdkit import Chem

# %%
from rdkit.Chem.Descriptors import MolWt, MolLogP, NumHDonors, NumHAcceptors

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
